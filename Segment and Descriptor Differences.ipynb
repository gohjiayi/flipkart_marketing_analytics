# %% [markdown]
# # Segment and Descriptor Differences
# This notebook aims to derive population differences using segmentation and descriptor variables.

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
# !pip install -qqq Xlsxwriter
# Out:
#      |████████████████████████████████| 149 kB 5.7 MB/s

# %%
import os
import pandas as pd
import numpy as np
import xlsxwriter
from scipy import stats

# %%
# Change to your own directory
try:
    os.chdir("/content/drive/MyDrive/BT4211 Data-driven Marketing")
    print("Directory changed")
except OSError:
    print("Error: Can't change the Current Working Directory")
# Out:
# Directory changed

# %% [markdown]
# ## Load datasets

# %% [markdown]
# ### Segment and RFM data

# %%
rfm_seg2_df = pd.read_csv('Data/RFM_2_segment.csv')
rfm_seg2_df.shape
# Out:
# (293, 5)

# %%
rfm_seg3_df = pd.read_csv('Data/RFM_3_segment.csv')
rfm_seg3_df.shape
# Out:
# (293, 5)

# %%
rfm_seg4_df = pd.read_csv('Data/RFM_4_segment.csv')
rfm_seg4_df.shape
# Out:
# (293, 5)

# %%
rfm_seg5_df = pd.read_csv('Data/RFM_5_segment.csv')
rfm_seg5_df.shape
# Out:
# (293, 5)

# %% [markdown]
# ### Psychometric and Demographic Numerical data

# %%
psycho_demo_num_df = pd.read_csv('Data/psycho_demo_num.csv')
psycho_demo_num_df.shape
# Out:
# (303, 64)

# %% [markdown]
# ### Psychometric Aggregated data

# %%
psycho_demo_agg_df = pd.read_csv('Data/psycho_demo_agg.csv')
psycho_demo_agg_df.shape
# Out:
# (303, 9)

# %% [markdown]
# ### Factorised data

# %%
factor_df = pd.read_csv('Data/factor_features.csv')
factor_df.shape
# Out:
# (303, 19)

# %% [markdown]
# ## Define functions

# %%
def get_segment_diff_pval(segments_dict, population_mean, diff_decimal=2, pval_decimal=4):
  """Get mean and pvalue for each segment."""

  # Initialise dataframes
  segment_diff_df = pd.DataFrame(columns=['Descriptor Variable', 'Population Mean'] + list(segments_dict.keys()))
  segment_pvalue_df = pd.DataFrame(columns=['Descriptor Variable'] + list(segments_dict.keys()))

  for column, pop_mean in population_mean.iteritems():
    # Initialise dicts to store row information for each column
    new_segment_diff_row = {'Descriptor Variable': column, 'Population Mean': round(pop_mean, diff_decimal)}
    new_segment_pvalue_row = {'Descriptor Variable': column}

    # Calculate mean and pvalue for each segment
    for segment, segment_df in segments_dict.items():
      tscore, pvalue = stats.ttest_1samp(segment_df[column], popmean=pop_mean)
      new_segment_diff_row[segment] = round(segment_df[column].mean(), diff_decimal)
      new_segment_pvalue_row[segment] = round(pvalue, pval_decimal)

    # Update dataframe
    segment_diff_df = segment_diff_df.append(new_segment_diff_row, ignore_index=True)
    segment_pvalue_df = segment_pvalue_df.append(new_segment_pvalue_row, ignore_index=True)

  return segment_diff_df, segment_pvalue_df

# %%
def get_sig_diff(segment_dict, segment_diff_df, segment_pval_df):
  """Highlight significant differences for segment."""

  sig_diff_df = pd.DataFrame(columns=["Customer", "Variable", "Type", "Segment Mean", "Population Mean", "P-value"])

  for i, row in segment_diff_df.iterrows():
    column = row['Descriptor Variable']
    pop_mean = row['Population Mean']
    
    for segment in segment_dict.keys():
      segment_mean = row[segment]
      segment_pvalue = segment_pval_df[segment_pval_df['Descriptor Variable']==column][segment].to_numpy()[0]
      if segment_pvalue < 0.05 and segment_mean >= pop_mean: # Higher (p-value < 0.05)
        new_row = {"Customer": segment, "Variable": column, "Type": "Higher (p-val < 0.05)", "Segment Mean": segment_mean, "Population Mean": pop_mean, "P-value": segment_pvalue}
        sig_diff_df = sig_diff_df.append(new_row, ignore_index=True)
      elif segment_pvalue < 0.10 and segment_pvalue >= 0.05 and segment_mean >= pop_mean: # Higher (p-value < 0.10)
        new_row = {"Customer": segment, "Variable": column, "Type": "Higher (p-val < 0.10)", "Segment Mean": segment_mean, "Population Mean": pop_mean, "P-value": segment_pvalue}
        sig_diff_df = sig_diff_df.append(new_row, ignore_index=True)
      elif segment_pvalue < 0.05 and segment_mean <= pop_mean: # Lower (p-value < 0.05)
        new_row = {"Customer": segment, "Variable": column, "Type": "Lower (p-val < 0.05)", "Segment Mean": segment_mean, "Population Mean": pop_mean, "P-value": segment_pvalue}
        sig_diff_df = sig_diff_df.append(new_row, ignore_index=True)
      elif segment_pvalue < 0.10 and segment_pvalue > 0.05 and segment_mean <= pop_mean: # Lower (p-value < 0.10)
        new_row = {"Customer": segment, "Variable": column, "Type": "Lower (p-val < 0.10)", "Segment Mean": segment_mean, "Population Mean": pop_mean, "P-value": segment_pvalue}
        sig_diff_df = sig_diff_df.append(new_row, ignore_index=True)
      
  return sig_diff_df

# %% [markdown]
# ## Numeric Data

# %% [markdown]
# ### Merge datasets

# %%
# Merge datasets
merged_seg2_df = rfm_seg2_df.merge(psycho_demo_num_df, on='Name')
merged_seg3_df = rfm_seg3_df.merge(psycho_demo_num_df, on='Name')
merged_seg4_df = rfm_seg4_df.merge(psycho_demo_num_df, on='Name')
merged_seg5_df = rfm_seg5_df.merge(psycho_demo_num_df, on='Name')

# %% [markdown]
# ### Load segments

# %%
high_segment_df = merged_seg2_df[merged_seg2_df['Cluster'] == "High Value Customer"]
low_segment_df = merged_seg2_df[merged_seg2_df['Cluster'] == "Low Value Customer"]

seg2_dict = {'High Value Customer': high_segment_df,
              'Low Value Customer': low_segment_df}

# %%
high_segment_df = merged_seg3_df[merged_seg3_df['Cluster'] == "High Value Customer"]
medium_segment_df = merged_seg3_df[merged_seg3_df['Cluster'] == "Medium Value Customer"]
low_segment_df = merged_seg3_df[merged_seg3_df['Cluster'] == "Low Value Customer"]

seg3_dict = {'High Value Customer': high_segment_df,
              'Medium Value Customer': medium_segment_df,
              'Low Value Customer': low_segment_df}

# %%
high_segment_df = merged_seg4_df[merged_seg4_df['Cluster'] == "High Value Customer"]
medium_segment_df = merged_seg4_df[merged_seg4_df['Cluster'] == "Medium Value Customer"]
low_segment_df = merged_seg4_df[merged_seg4_df['Cluster'] == "Low Value Customer"]
lost_segment_df = merged_seg4_df[merged_seg4_df['Cluster'] == "Lost Customer"]

seg4_dict = {'High Value Customer': high_segment_df,
              'Medium Value Customer': medium_segment_df,
              'Low Value Customer': low_segment_df,
              'Lost Customer': lost_segment_df}

# %%
top_segment_df = merged_seg5_df[merged_seg5_df['Cluster'] == "Top Customer"]
high_segment_df = merged_seg5_df[merged_seg5_df['Cluster'] == "High Value Customer"]
medium_segment_df = merged_seg5_df[merged_seg5_df['Cluster'] == "Medium Value Customer"]
low_segment_df = merged_seg5_df[merged_seg5_df['Cluster'] == "Low Value Customer"]
lost_segment_df = merged_seg5_df[merged_seg5_df['Cluster'] == "Lost Customer"]

seg5_dict = {'Top Customer': top_segment_df,
            'High Value Customer': high_segment_df,
            'Medium Value Customer': medium_segment_df,
            'Low Value Customer': low_segment_df,
            'Lost Customer': lost_segment_df}

# %% [markdown]
# ### Segment Differences Calculation

# %% [markdown]
# #### Segmentation Variables

# %%
# Get segmentation variables population mean
seg2_pop_mean = rfm_seg2_df.mean(numeric_only=True)
seg3_pop_mean = rfm_seg3_df.mean(numeric_only=True)
seg4_pop_mean = rfm_seg4_df.mean(numeric_only=True)
seg5_pop_mean = rfm_seg5_df.mean(numeric_only=True)

# %%
# Get segment differences and pvalues
seg2_seg_diff_df, seg2_seg_pval_df = get_segment_diff_pval(seg2_dict, seg2_pop_mean)
seg3_seg_diff_df, seg3_seg_pval_df = get_segment_diff_pval(seg3_dict, seg3_pop_mean)
seg4_seg_diff_df, seg4_seg_pval_df = get_segment_diff_pval(seg4_dict, seg4_pop_mean)
seg5_seg_diff_df, seg5_seg_pval_df = get_segment_diff_pval(seg5_dict, seg5_pop_mean)

# %%
# Write to excel
options = {}
options['strings_to_formulas'] = False
options['strings_to_urls'] = False

with pd.ExcelWriter('Data/segmentation_num_diff_pval.xlsx', options=options) as writer:  
  seg2_seg_diff_df.to_excel(writer, sheet_name='2 Mean', index=False)
  seg2_seg_pval_df.to_excel(writer, sheet_name='2 P-val', index=False)

  seg3_seg_diff_df.to_excel(writer, sheet_name='3 Mean', index=False)
  seg3_seg_pval_df.to_excel(writer, sheet_name='3 P-val', index=False)

  seg4_seg_diff_df.to_excel(writer, sheet_name='4 Mean', index=False)
  seg4_seg_pval_df.to_excel(writer, sheet_name='4 P-val', index=False)

  seg5_seg_diff_df.to_excel(writer, sheet_name='5 Mean', index=False)
  seg5_seg_pval_df.to_excel(writer, sheet_name='5 P-val', index=False)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:6: FutureWarning: Use of **kwargs is deprecated, use engine_kwargs instead.

# %% [markdown]
# #### Descriptor Variables

# %%
# Get descriptor variables population mean
desc_pop_mean = psycho_demo_num_df.mean(numeric_only=True)

# %%
# Get segment differences and pvalues
seg2_desc_diff_df, seg2_desc_pval_df = get_segment_diff_pval(seg2_dict, desc_pop_mean)
seg3_desc_diff_df, seg3_desc_pval_df = get_segment_diff_pval(seg3_dict, desc_pop_mean)
seg4_desc_diff_df, seg4_desc_pval_df = get_segment_diff_pval(seg4_dict, desc_pop_mean)
seg5_desc_diff_df, seg5_desc_pval_df = get_segment_diff_pval(seg5_dict, desc_pop_mean)

# %%
# Write to excel
options = {}
options['strings_to_formulas'] = False
options['strings_to_urls'] = False

with pd.ExcelWriter('Data/descriptor_num_diff_pval.xlsx', options=options) as writer:  
  seg2_desc_diff_df.to_excel(writer, sheet_name='2 Mean', index=False)
  seg2_desc_pval_df.to_excel(writer, sheet_name='2 P-val', index=False)

  seg3_desc_diff_df.to_excel(writer, sheet_name='3 Mean', index=False)
  seg3_desc_pval_df.to_excel(writer, sheet_name='3 P-val', index=False)

  seg4_desc_diff_df.to_excel(writer, sheet_name='4 Mean', index=False)
  seg4_desc_pval_df.to_excel(writer, sheet_name='4 P-val', index=False)

  seg5_desc_diff_df.to_excel(writer, sheet_name='5 Mean', index=False)
  seg5_desc_pval_df.to_excel(writer, sheet_name='5 P-val', index=False)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:6: FutureWarning: Use of **kwargs is deprecated, use engine_kwargs instead.

# %% [markdown]
# ### Analyse Significant Differences

# %% [markdown]
# #### Segmentation Variables

# %%
seg2_seg_sig_diff = get_sig_diff(seg2_dict, seg2_seg_diff_df, seg2_seg_pval_df)
seg2_seg_sig_diff.sort_values("Customer")
# Out:
#               Customer        Variable                   Type  Segment Mean  \
# 0  High Value Customer         recency   Lower (p-val < 0.05)        112.35
# 2  High Value Customer       frequency  Higher (p-val < 0.05)         17.13
# 4  High Value Customer  monetary_value  Higher (p-val < 0.05)      31382.92
# 1   Low Value Customer         recency  Higher (p-val < 0.05)        341.80
# 3   Low Value Customer       frequency   Lower (p-val < 0.05)          3.70
# 5   Low Value Customer  monetary_value   Lower (p-val < 0.05)      10128.95
#
#    Population Mean  P-value
# 0           232.44    0.000
# 2            10.13    0.000
# 4         20070.56    0.002
# 1           232.44    0.000
# 3            10.13    0.000
# 5         20070.56    0.000

# %%
seg3_seg_sig_diff = get_sig_diff(seg3_dict, seg3_seg_diff_df, seg3_seg_pval_df)
seg3_seg_sig_diff.sort_values("Customer")
# Out:
#                 Customer        Variable                   Type  Segment Mean  \
# 0    High Value Customer         recency   Lower (p-val < 0.05)         64.98
# 3    High Value Customer       frequency  Higher (p-val < 0.05)         26.26
# 5    High Value Customer  monetary_value  Higher (p-val < 0.05)      41731.24
# 2     Low Value Customer         recency  Higher (p-val < 0.05)        341.80
# 4     Low Value Customer       frequency   Lower (p-val < 0.05)          3.70
# 6     Low Value Customer  monetary_value   Lower (p-val < 0.05)      10128.95
# 1  Medium Value Customer         recency   Lower (p-val < 0.05)        147.13
#
#    Population Mean  P-value
# 0           232.44   0.0000
# 3            10.13   0.0000
# 5         20070.56   0.0025
# 2           232.44   0.0000
# 4            10.13   0.0000
# 6         20070.56   0.0000
# 1           232.44   0.0000

# %%
seg4_seg_sig_diff = get_sig_diff(seg4_dict, seg4_seg_diff_df, seg4_seg_pval_df)
seg4_seg_sig_diff.sort_values("Customer")
# Out:
#                 Customer        Variable                   Type  Segment Mean  \
# 0    High Value Customer         recency   Lower (p-val < 0.05)         64.98
# 3    High Value Customer       frequency  Higher (p-val < 0.05)         26.26
# 6    High Value Customer  monetary_value  Higher (p-val < 0.05)      41731.24
# 2          Lost Customer         recency  Higher (p-val < 0.05)        505.38
# 5          Lost Customer       frequency   Lower (p-val < 0.05)          2.12
# 8          Lost Customer  monetary_value   Lower (p-val < 0.05)       7805.17
# 4     Low Value Customer       frequency   Lower (p-val < 0.05)          4.55
# 7     Low Value Customer  monetary_value   Lower (p-val < 0.05)      11387.67
# 1  Medium Value Customer         recency   Lower (p-val < 0.05)        147.13
#
#    Population Mean  P-value
# 0           232.44   0.0000
# 3            10.13   0.0000
# 6         20070.56   0.0025
# 2           232.44   0.0000
# 5            10.13   0.0000
# 8         20070.56   0.0000
# 4            10.13   0.0000
# 7         20070.56   0.0000
# 1           232.44   0.0000

# %%
seg5_seg_sig_diff = get_sig_diff(seg5_dict, seg5_seg_diff_df, seg5_seg_pval_df)
seg5_seg_sig_diff.sort_values("Customer")
# Out:
#                  Customer        Variable                   Type  \
# 1     High Value Customer         recency   Lower (p-val < 0.05)
# 6     High Value Customer       frequency  Higher (p-val < 0.05)
# 11    High Value Customer  monetary_value  Higher (p-val < 0.05)
# 4           Lost Customer         recency  Higher (p-val < 0.05)
# 9           Lost Customer       frequency   Lower (p-val < 0.05)
# 14          Lost Customer  monetary_value   Lower (p-val < 0.05)
# 3      Low Value Customer         recency  Higher (p-val < 0.05)
# 8      Low Value Customer       frequency   Lower (p-val < 0.05)
# 13     Low Value Customer  monetary_value   Lower (p-val < 0.05)
# 2   Medium Value Customer         recency   Lower (p-val < 0.05)
# 7   Medium Value Customer       frequency   Lower (p-val < 0.05)
# 12  Medium Value Customer  monetary_value   Lower (p-val < 0.05)
# 0            Top Customer         recency   Lower (p-val < 0.05)
# 5            Top Customer       frequency  Higher (p-val < 0.05)
# 10           Top Customer  monetary_value  Higher (p-val < 0.05)
#
#     Segment Mean  Population Mean  P-value
# 1         111.08           232.44   0.0000
# 6          13.77            10.13   0.0028
# 11      29561.48         20070.56   0.0249
# 4         534.12           232.44   0.0000
# 9           1.78            10.13   0.0000
# 14       7955.61         20070.56   0.0000
# 3         296.20           232.44   0.0020
# 8           3.83            10.13   0.0000
# 13       9915.65         20070.56   0.0000
# 2         199.12           232.44   0.0309
# 7           6.57            10.13   0.0000
# 12      13903.18         20070.56   0.0014
# 0          57.22           232.44   0.0000
# 5          30.18            10.13   0.0000
# 10      47536.05         20070.56   0.0066

# %% [markdown]
# #### Descriptor Variables

# %%
seg2_desc_sig_diff = get_sig_diff(seg2_dict, seg2_desc_diff_df, seg2_desc_pval_df)
seg2_desc_sig_diff.sort_values("Customer")
# Out:
#               Customer                                           Variable  \
# 0  High Value Customer  When making a decision, I take other people's ...
# 1  High Value Customer     I walk/cycle/use public transport to save fuel
# 3  High Value Customer                                          Has Child
# 5  High Value Customer              Preferred Mode of Payment_Net Banking
# 6  High Value Customer           Preferred Mode of Payment_Online Wallets
# 7  High Value Customer                           Care for Chronic Illness
# 2   Low Value Customer     I walk/cycle/use public transport to save fuel
# 4   Low Value Customer                                         Meditation
# 8   Low Value Customer                           Care for Chronic Illness
#
#                     Type  Segment Mean  Population Mean  P-value
# 0  Higher (p-val < 0.10)          5.79             5.62   0.0510
# 1   Lower (p-val < 0.05)          4.69             5.00   0.0334
# 3   Lower (p-val < 0.10)          0.09             0.14   0.0510
# 5   Lower (p-val < 0.05)          0.01             0.03   0.0099
# 6   Lower (p-val < 0.05)          0.01             0.02   0.0321
# 7   Lower (p-val < 0.05)          0.07             0.14   0.0060
# 2  Higher (p-val < 0.10)          5.23             5.00   0.0980
# 4  Higher (p-val < 0.10)          0.53             0.45   0.0596
# 8  Higher (p-val < 0.10)          0.19             0.14   0.0975

# %%
seg3_desc_sig_diff = get_sig_diff(seg3_dict, seg3_desc_diff_df, seg3_desc_pval_df)
seg3_desc_sig_diff.sort_values("Customer")
# Out:
#                  Customer                                           Variable  \
# 0     High Value Customer  If I could live my life over, I would change a...
# 7     High Value Customer              Preferred Mode of Payment_Credit Card
# 9     High Value Customer           Preferred Mode of Payment_Online Wallets
# 4      Low Value Customer     I walk/cycle/use public transport to save fuel
# 6      Low Value Customer                                         Meditation
# 11     Low Value Customer                           Care for Chronic Illness
# 1   Medium Value Customer          I feel good when I co-operate with others
# 2   Medium Value Customer  When making a decision, I take other people's ...
# 3   Medium Value Customer  It is my duty to take care of my family, even ...
# 5   Medium Value Customer                                          Has Child
# 8   Medium Value Customer              Preferred Mode of Payment_Net Banking
# 10  Medium Value Customer                           Care for Chronic Illness
#
#                      Type  Segment Mean  Population Mean  P-value
# 0   Higher (p-val < 0.05)          4.64             4.21   0.0465
# 7   Higher (p-val < 0.10)          0.17             0.07   0.0509
# 9    Lower (p-val < 0.05)          0.00             0.02   0.0000
# 4   Higher (p-val < 0.10)          5.23             5.00   0.0980
# 6   Higher (p-val < 0.10)          0.53             0.45   0.0596
# 11  Higher (p-val < 0.10)          0.19             0.14   0.0975
# 1   Higher (p-val < 0.10)          6.20             6.02   0.0520
# 2   Higher (p-val < 0.10)          5.82             5.62   0.0670
# 3   Higher (p-val < 0.05)          6.19             5.96   0.0298
# 5    Lower (p-val < 0.05)          0.06             0.14   0.0108
# 8    Lower (p-val < 0.05)          0.00             0.03   0.0000
# 10   Lower (p-val < 0.05)          0.06             0.14   0.0108

# %%
seg4_desc_sig_diff = get_sig_diff(seg4_dict, seg4_desc_diff_df, seg4_desc_pval_df)
seg4_desc_sig_diff.sort_values("Customer")
# Out:
#                  Customer                                           Variable  \
# 0     High Value Customer  If I could live my life over, I would change a...
# 12    High Value Customer              Preferred Mode of Payment_Credit Card
# 15    High Value Customer           Preferred Mode of Payment_Online Wallets
# 13          Lost Customer              Preferred Mode of Payment_Credit Card
# 6           Lost Customer  I believe success in life does not mean becomi...
# 8           Lost Customer                                                Age
# 4           Lost Customer  It upsets me when my work is not recognized by...
# 7      Low Value Customer     I walk/cycle/use public transport to save fuel
# 10     Low Value Customer                                          Has Child
# 11     Low Value Customer                                         Meditation
# 5      Low Value Customer  I believe success in life does not mean becomi...
# 3   Medium Value Customer  It is my duty to take care of my family, even ...
# 9   Medium Value Customer                                          Has Child
# 2   Medium Value Customer  When making a decision, I take other people's ...
# 1   Medium Value Customer          I feel good when I co-operate with others
# 14  Medium Value Customer              Preferred Mode of Payment_Net Banking
# 16  Medium Value Customer                           Care for Chronic Illness
#
#                      Type  Segment Mean  Population Mean  P-value
# 0   Higher (p-val < 0.05)          4.64             4.21   0.0465
# 12  Higher (p-val < 0.10)          0.17             0.07   0.0509
# 15   Lower (p-val < 0.05)          0.00             0.02   0.0000
# 13   Lower (p-val < 0.05)          0.00             0.07   0.0000
# 6    Lower (p-val < 0.10)          5.19             5.56   0.0579
# 8    Lower (p-val < 0.05)         24.38            26.32   0.0009
# 4   Higher (p-val < 0.10)          5.46             5.11   0.0542
# 7   Higher (p-val < 0.05)          5.33             5.00   0.0466
# 10  Higher (p-val < 0.10)          0.21             0.14   0.0829
# 11  Higher (p-val < 0.05)          0.55             0.45   0.0458
# 5   Higher (p-val < 0.10)          5.80             5.56   0.0761
# 3   Higher (p-val < 0.05)          6.19             5.96   0.0298
# 9    Lower (p-val < 0.05)          0.06             0.14   0.0108
# 2   Higher (p-val < 0.10)          5.82             5.62   0.0670
# 1   Higher (p-val < 0.10)          6.20             6.02   0.0520
# 14   Lower (p-val < 0.05)          0.00             0.03   0.0000
# 16   Lower (p-val < 0.05)          0.06             0.14   0.0108

# %%
seg5_desc_sig_diff = get_sig_diff(seg5_dict, seg5_desc_diff_df, seg5_desc_pval_df)
seg5_desc_sig_diff.sort_values("Customer")
# Out:
#                  Customer                                           Variable  \
# 10    High Value Customer                                         Meditation
# 1     High Value Customer          I feel good when I co-operate with others
# 3     High Value Customer  It is important that I do my job better than o...
# 17    High Value Customer              Preferred Mode of Payment_Net Banking
# 15    High Value Customer               Preferred Mode of Payment_Debit Card
# 12    High Value Customer                               Meditation Frequency
# 9     High Value Customer                                          Has Child
# 19    High Value Customer                           Care for Chronic Illness
# 2           Lost Customer          I feel good when I co-operate with others
# 14          Lost Customer              Preferred Mode of Payment_Credit Card
# 8           Lost Customer                                                Age
# 20     Low Value Customer                           Care for Chronic Illness
# 7      Low Value Customer     I walk/cycle/use public transport to save fuel
# 5      Low Value Customer  I admire people who own expensive homes, cars,...
# 4      Low Value Customer            Traditional values are important for me
# 11     Low Value Customer                                         Meditation
# 13  Medium Value Customer              Preferred Mode of Payment_Credit Card
# 6   Medium Value Customer                            I try to conserve water
# 16  Medium Value Customer               Preferred Mode of Payment_Debit Card
# 18           Top Customer           Preferred Mode of Payment_Online Wallets
# 0            Top Customer                                      Hobbies Count
#
#                      Type  Segment Mean  Population Mean  P-value
# 10   Lower (p-val < 0.05)          0.32             0.45   0.0352
# 1   Higher (p-val < 0.05)          6.25             6.02   0.0403
# 3    Lower (p-val < 0.10)          5.03             5.37   0.0958
# 17   Lower (p-val < 0.05)          0.00             0.03   0.0000
# 15   Lower (p-val < 0.10)          0.03             0.07   0.0570
# 12   Lower (p-val < 0.10)          0.69             0.92   0.0826
# 9    Lower (p-val < 0.10)          0.08             0.14   0.0844
# 19   Lower (p-val < 0.05)          0.03             0.14   0.0000
# 2   Higher (p-val < 0.10)          6.27             6.02   0.0613
# 14   Lower (p-val < 0.05)          0.00             0.07   0.0000
# 8    Lower (p-val < 0.05)         24.10            26.32   0.0015
# 20  Higher (p-val < 0.05)          0.27             0.14   0.0148
# 7   Higher (p-val < 0.05)          5.48             5.00   0.0116
# 5   Higher (p-val < 0.05)          4.82             4.23   0.0049
# 4   Higher (p-val < 0.10)          5.65             5.33   0.0523
# 11  Higher (p-val < 0.05)          0.58             0.45   0.0327
# 13   Lower (p-val < 0.05)          0.03             0.07   0.0402
# 6    Lower (p-val < 0.05)          5.57             5.92   0.0305
# 16  Higher (p-val < 0.10)          0.16             0.07   0.0516
# 18   Lower (p-val < 0.05)          0.00             0.02   0.0000
# 0    Lower (p-val < 0.10)          1.60             1.82   0.0913

# %% [markdown]
# ## Aggregated Data

# %% [markdown]
# ### Merge datasets

# %%
# Merge datasets
merged_seg2_df = rfm_seg2_df.merge(psycho_demo_agg_df, on='Name')
merged_seg3_df = rfm_seg3_df.merge(psycho_demo_agg_df, on='Name')
merged_seg4_df = rfm_seg4_df.merge(psycho_demo_agg_df, on='Name')
merged_seg5_df = rfm_seg5_df.merge(psycho_demo_agg_df, on='Name')

# %% [markdown]
# ### Load segments

# %%
high_segment_df = merged_seg2_df[merged_seg2_df['Cluster'] == "High Value Customer"]
low_segment_df = merged_seg2_df[merged_seg2_df['Cluster'] == "Low Value Customer"]

seg2_dict = {'High Value Customer': high_segment_df,
              'Low Value Customer': low_segment_df}

# %%
high_segment_df = merged_seg3_df[merged_seg3_df['Cluster'] == "High Value Customer"]
medium_segment_df = merged_seg3_df[merged_seg3_df['Cluster'] == "Medium Value Customer"]
low_segment_df = merged_seg3_df[merged_seg3_df['Cluster'] == "Low Value Customer"]

seg3_dict = {'High Value Customer': high_segment_df,
              'Medium Value Customer': medium_segment_df,
              'Low Value Customer': low_segment_df}

# %%
high_segment_df = merged_seg4_df[merged_seg4_df['Cluster'] == "High Value Customer"]
medium_segment_df = merged_seg4_df[merged_seg4_df['Cluster'] == "Medium Value Customer"]
low_segment_df = merged_seg4_df[merged_seg4_df['Cluster'] == "Low Value Customer"]
lost_segment_df = merged_seg4_df[merged_seg4_df['Cluster'] == "Lost Customer"]

seg4_dict = {'High Value Customer': high_segment_df,
              'Medium Value Customer': medium_segment_df,
              'Low Value Customer': low_segment_df,
              'Lost Customer': lost_segment_df}

# %%
top_segment_df = merged_seg5_df[merged_seg5_df['Cluster'] == "Top Customer"]
high_segment_df = merged_seg5_df[merged_seg5_df['Cluster'] == "High Value Customer"]
medium_segment_df = merged_seg5_df[merged_seg5_df['Cluster'] == "Medium Value Customer"]
low_segment_df = merged_seg5_df[merged_seg5_df['Cluster'] == "Low Value Customer"]
lost_segment_df = merged_seg5_df[merged_seg5_df['Cluster'] == "Lost Customer"]

seg5_dict = {'Top Customer': top_segment_df,
            'High Value Customer': high_segment_df,
            'Medium Value Customer': medium_segment_df,
            'Low Value Customer': low_segment_df,
            'Lost Customer': lost_segment_df}

# %% [markdown]
# ### Segment Differences Calculation

# %% [markdown]
# #### Segmentation Variables

# %%
# Get segmentation variables population mean
seg2_pop_mean = rfm_seg2_df.mean(numeric_only=True)
seg3_pop_mean = rfm_seg3_df.mean(numeric_only=True)
seg4_pop_mean = rfm_seg4_df.mean(numeric_only=True)
seg5_pop_mean = rfm_seg5_df.mean(numeric_only=True)

# %%
# Get segment differences and pvalues
seg2_seg_diff_df, seg2_seg_pval_df = get_segment_diff_pval(seg2_dict, seg2_pop_mean)
seg3_seg_diff_df, seg3_seg_pval_df = get_segment_diff_pval(seg3_dict, seg3_pop_mean)
seg4_seg_diff_df, seg4_seg_pval_df = get_segment_diff_pval(seg4_dict, seg4_pop_mean)
seg5_seg_diff_df, seg5_seg_pval_df = get_segment_diff_pval(seg5_dict, seg5_pop_mean)

# %%
# Write to excel
options = {}
options['strings_to_formulas'] = False
options['strings_to_urls'] = False

with pd.ExcelWriter('Data/segmentation_agg_diff_pval.xlsx', options=options) as writer:  
  seg2_seg_diff_df.to_excel(writer, sheet_name='2 Mean', index=False)
  seg2_seg_pval_df.to_excel(writer, sheet_name='2 P-val', index=False)

  seg3_seg_diff_df.to_excel(writer, sheet_name='3 Mean', index=False)
  seg3_seg_pval_df.to_excel(writer, sheet_name='3 P-val', index=False)

  seg4_seg_diff_df.to_excel(writer, sheet_name='4 Mean', index=False)
  seg4_seg_pval_df.to_excel(writer, sheet_name='4 P-val', index=False)

  seg5_seg_diff_df.to_excel(writer, sheet_name='5 Mean', index=False)
  seg5_seg_pval_df.to_excel(writer, sheet_name='5 P-val', index=False)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:6: FutureWarning: Use of **kwargs is deprecated, use engine_kwargs instead.

# %% [markdown]
# #### Descriptor Variables

# %%
# Get descriptor variables population mean
desc_pop_mean = psycho_demo_agg_df.mean(numeric_only=True)

# %%
# Get segment differences and pvalues
seg2_desc_diff_df, seg2_desc_pval_df = get_segment_diff_pval(seg2_dict, desc_pop_mean)
seg3_desc_diff_df, seg3_desc_pval_df = get_segment_diff_pval(seg3_dict, desc_pop_mean)
seg4_desc_diff_df, seg4_desc_pval_df = get_segment_diff_pval(seg4_dict, desc_pop_mean)
seg5_desc_diff_df, seg5_desc_pval_df = get_segment_diff_pval(seg5_dict, desc_pop_mean)

# %%
# Write to excel
options = {}
options['strings_to_formulas'] = False
options['strings_to_urls'] = False

with pd.ExcelWriter('Data/descriptor_agg_diff_pval.xlsx', options=options) as writer:  
  seg2_desc_diff_df.to_excel(writer, sheet_name='2 Mean', index=False)
  seg2_desc_pval_df.to_excel(writer, sheet_name='2 P-val', index=False)

  seg3_desc_diff_df.to_excel(writer, sheet_name='3 Mean', index=False)
  seg3_desc_pval_df.to_excel(writer, sheet_name='3 P-val', index=False)

  seg4_desc_diff_df.to_excel(writer, sheet_name='4 Mean', index=False)
  seg4_desc_pval_df.to_excel(writer, sheet_name='4 P-val', index=False)

  seg5_desc_diff_df.to_excel(writer, sheet_name='5 Mean', index=False)
  seg5_desc_pval_df.to_excel(writer, sheet_name='5 P-val', index=False)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:6: FutureWarning: Use of **kwargs is deprecated, use engine_kwargs instead.

# %% [markdown]
# ### Analyse Significant Differences

# %% [markdown]
# #### Segmentation Variables

# %%
seg2_seg_sig_diff = get_sig_diff(seg2_dict, seg2_seg_diff_df, seg2_seg_pval_df)
seg2_seg_sig_diff.sort_values("Customer")
# Out:
#               Customer        Variable                   Type  Segment Mean  \
# 0  High Value Customer         recency   Lower (p-val < 0.05)        112.35
# 2  High Value Customer       frequency  Higher (p-val < 0.05)         17.13
# 4  High Value Customer  monetary_value  Higher (p-val < 0.05)      31382.92
# 1   Low Value Customer         recency  Higher (p-val < 0.05)        341.80
# 3   Low Value Customer       frequency   Lower (p-val < 0.05)          3.70
# 5   Low Value Customer  monetary_value   Lower (p-val < 0.05)      10128.95
#
#    Population Mean  P-value
# 0           232.44    0.000
# 2            10.13    0.000
# 4         20070.56    0.002
# 1           232.44    0.000
# 3            10.13    0.000
# 5         20070.56    0.000

# %%
seg3_seg_sig_diff = get_sig_diff(seg3_dict, seg3_seg_diff_df, seg3_seg_pval_df)
seg3_seg_sig_diff.sort_values("Customer")
# Out:
#                 Customer        Variable                   Type  Segment Mean  \
# 0    High Value Customer         recency   Lower (p-val < 0.05)         64.98
# 3    High Value Customer       frequency  Higher (p-val < 0.05)         26.26
# 5    High Value Customer  monetary_value  Higher (p-val < 0.05)      41731.24
# 2     Low Value Customer         recency  Higher (p-val < 0.05)        341.80
# 4     Low Value Customer       frequency   Lower (p-val < 0.05)          3.70
# 6     Low Value Customer  monetary_value   Lower (p-val < 0.05)      10128.95
# 1  Medium Value Customer         recency   Lower (p-val < 0.05)        147.13
#
#    Population Mean  P-value
# 0           232.44   0.0000
# 3            10.13   0.0000
# 5         20070.56   0.0025
# 2           232.44   0.0000
# 4            10.13   0.0000
# 6         20070.56   0.0000
# 1           232.44   0.0000

# %%
seg4_seg_sig_diff = get_sig_diff(seg4_dict, seg4_seg_diff_df, seg4_seg_pval_df)
seg4_seg_sig_diff.sort_values("Customer")
# Out:
#                 Customer        Variable                   Type  Segment Mean  \
# 0    High Value Customer         recency   Lower (p-val < 0.05)         64.98
# 3    High Value Customer       frequency  Higher (p-val < 0.05)         26.26
# 6    High Value Customer  monetary_value  Higher (p-val < 0.05)      41731.24
# 2          Lost Customer         recency  Higher (p-val < 0.05)        505.38
# 5          Lost Customer       frequency   Lower (p-val < 0.05)          2.12
# 8          Lost Customer  monetary_value   Lower (p-val < 0.05)       7805.17
# 4     Low Value Customer       frequency   Lower (p-val < 0.05)          4.55
# 7     Low Value Customer  monetary_value   Lower (p-val < 0.05)      11387.67
# 1  Medium Value Customer         recency   Lower (p-val < 0.05)        147.13
#
#    Population Mean  P-value
# 0           232.44   0.0000
# 3            10.13   0.0000
# 6         20070.56   0.0025
# 2           232.44   0.0000
# 5            10.13   0.0000
# 8         20070.56   0.0000
# 4            10.13   0.0000
# 7         20070.56   0.0000
# 1           232.44   0.0000

# %%
seg5_seg_sig_diff = get_sig_diff(seg5_dict, seg5_seg_diff_df, seg5_seg_pval_df)
seg5_seg_sig_diff.sort_values("Customer")
# Out:
#                  Customer        Variable                   Type  \
# 1     High Value Customer         recency   Lower (p-val < 0.05)
# 6     High Value Customer       frequency  Higher (p-val < 0.05)
# 11    High Value Customer  monetary_value  Higher (p-val < 0.05)
# 4           Lost Customer         recency  Higher (p-val < 0.05)
# 9           Lost Customer       frequency   Lower (p-val < 0.05)
# 14          Lost Customer  monetary_value   Lower (p-val < 0.05)
# 3      Low Value Customer         recency  Higher (p-val < 0.05)
# 8      Low Value Customer       frequency   Lower (p-val < 0.05)
# 13     Low Value Customer  monetary_value   Lower (p-val < 0.05)
# 2   Medium Value Customer         recency   Lower (p-val < 0.05)
# 7   Medium Value Customer       frequency   Lower (p-val < 0.05)
# 12  Medium Value Customer  monetary_value   Lower (p-val < 0.05)
# 0            Top Customer         recency   Lower (p-val < 0.05)
# 5            Top Customer       frequency  Higher (p-val < 0.05)
# 10           Top Customer  monetary_value  Higher (p-val < 0.05)
#
#     Segment Mean  Population Mean  P-value
# 1         111.08           232.44   0.0000
# 6          13.77            10.13   0.0028
# 11      29561.48         20070.56   0.0249
# 4         534.12           232.44   0.0000
# 9           1.78            10.13   0.0000
# 14       7955.61         20070.56   0.0000
# 3         296.20           232.44   0.0020
# 8           3.83            10.13   0.0000
# 13       9915.65         20070.56   0.0000
# 2         199.12           232.44   0.0309
# 7           6.57            10.13   0.0000
# 12      13903.18         20070.56   0.0014
# 0          57.22           232.44   0.0000
# 5          30.18            10.13   0.0000
# 10      47536.05         20070.56   0.0066

# %% [markdown]
# #### Descriptor Variables

# %%
seg2_desc_sig_diff = get_sig_diff(seg2_dict, seg2_desc_diff_df, seg2_desc_pval_df)
seg2_desc_sig_diff.sort_values("Customer")
# Out:
# Empty DataFrame
# Columns: [Customer, Variable, Type, Segment Mean, Population Mean, P-value]
# Index: []

# %%
seg3_desc_sig_diff = get_sig_diff(seg3_dict, seg3_desc_diff_df, seg3_desc_pval_df)
seg3_desc_sig_diff.sort_values("Customer")
# Out:
#                 Customer                   Variable                   Type  \
# 0  Medium Value Customer  Collectivism/Allocentrism  Higher (p-val < 0.05)
#
#    Segment Mean  Population Mean  P-value
# 0          5.89             5.73   0.0082

# %%
seg4_desc_sig_diff = get_sig_diff(seg4_dict, seg4_desc_diff_df, seg4_desc_pval_df)
seg4_desc_sig_diff.sort_values("Customer")
# Out:
#                 Customer                   Variable                   Type  \
# 0  Medium Value Customer  Collectivism/Allocentrism  Higher (p-val < 0.05)
#
#    Segment Mean  Population Mean  P-value
# 0          5.89             5.73   0.0082

# %%
seg5_desc_sig_diff = get_sig_diff(seg5_dict, seg5_desc_diff_df, seg5_desc_pval_df)
seg5_desc_sig_diff.sort_values("Customer")
# Out:
#              Customer                 Variable                   Type  \
# 0  Low Value Customer  Environmental Behaviour  Higher (p-val < 0.05)
#
#    Segment Mean  Population Mean  P-value
# 0          5.59             5.36    0.033

# %% [markdown]
# ## Factorised Data

# %% [markdown]
# ### Merge datasets

# %%
# Merge datasets
merged_seg2_df = rfm_seg2_df.merge(factor_df, on='Name')
merged_seg3_df = rfm_seg3_df.merge(factor_df, on='Name')
merged_seg4_df = rfm_seg4_df.merge(factor_df, on='Name')
merged_seg5_df = rfm_seg5_df.merge(factor_df, on='Name')

# %% [markdown]
# ### Load segments

# %%
high_segment_df = merged_seg2_df[merged_seg2_df['Cluster'] == "High Value Customer"]
low_segment_df = merged_seg2_df[merged_seg2_df['Cluster'] == "Low Value Customer"]

seg2_dict = {'High Value Customer': high_segment_df,
              'Low Value Customer': low_segment_df}

# %%
high_segment_df = merged_seg3_df[merged_seg3_df['Cluster'] == "High Value Customer"]
medium_segment_df = merged_seg3_df[merged_seg3_df['Cluster'] == "Medium Value Customer"]
low_segment_df = merged_seg3_df[merged_seg3_df['Cluster'] == "Low Value Customer"]

seg3_dict = {'High Value Customer': high_segment_df,
              'Medium Value Customer': medium_segment_df,
              'Low Value Customer': low_segment_df}

# %%
high_segment_df = merged_seg4_df[merged_seg4_df['Cluster'] == "High Value Customer"]
medium_segment_df = merged_seg4_df[merged_seg4_df['Cluster'] == "Medium Value Customer"]
low_segment_df = merged_seg4_df[merged_seg4_df['Cluster'] == "Low Value Customer"]
lost_segment_df = merged_seg4_df[merged_seg4_df['Cluster'] == "Lost Customer"]

seg4_dict = {'High Value Customer': high_segment_df,
              'Medium Value Customer': medium_segment_df,
              'Low Value Customer': low_segment_df,
              'Lost Customer': lost_segment_df}

# %%
top_segment_df = merged_seg5_df[merged_seg5_df['Cluster'] == "Top Customer"]
high_segment_df = merged_seg5_df[merged_seg5_df['Cluster'] == "High Value Customer"]
medium_segment_df = merged_seg5_df[merged_seg5_df['Cluster'] == "Medium Value Customer"]
low_segment_df = merged_seg5_df[merged_seg5_df['Cluster'] == "Low Value Customer"]
lost_segment_df = merged_seg5_df[merged_seg5_df['Cluster'] == "Lost Customer"]

seg5_dict = {'Top Customer': top_segment_df,
            'High Value Customer': high_segment_df,
            'Medium Value Customer': medium_segment_df,
            'Low Value Customer': low_segment_df,
            'Lost Customer': lost_segment_df}

# %% [markdown]
# ### Segment Differences Calculation

# %% [markdown]
# #### Segmentation Variables

# %%
# Get segmentation variables population mean
seg2_pop_mean = rfm_seg2_df.mean(numeric_only=True)
seg3_pop_mean = rfm_seg3_df.mean(numeric_only=True)
seg4_pop_mean = rfm_seg4_df.mean(numeric_only=True)
seg5_pop_mean = rfm_seg5_df.mean(numeric_only=True)

# %%
# Get segment differences and pvalues
seg2_seg_diff_df, seg2_seg_pval_df = get_segment_diff_pval(seg2_dict, seg2_pop_mean)
seg3_seg_diff_df, seg3_seg_pval_df = get_segment_diff_pval(seg3_dict, seg3_pop_mean)
seg4_seg_diff_df, seg4_seg_pval_df = get_segment_diff_pval(seg4_dict, seg4_pop_mean)
seg5_seg_diff_df, seg5_seg_pval_df = get_segment_diff_pval(seg5_dict, seg5_pop_mean)

# %%
# Write to excel
options = {}
options['strings_to_formulas'] = False
options['strings_to_urls'] = False

with pd.ExcelWriter('Data/segmentation_factorised_diff_pval.xlsx', options=options) as writer:  
  seg2_seg_diff_df.to_excel(writer, sheet_name='2 Mean', index=False)
  seg2_seg_pval_df.to_excel(writer, sheet_name='2 P-val', index=False)

  seg3_seg_diff_df.to_excel(writer, sheet_name='3 Mean', index=False)
  seg3_seg_pval_df.to_excel(writer, sheet_name='3 P-val', index=False)

  seg4_seg_diff_df.to_excel(writer, sheet_name='4 Mean', index=False)
  seg4_seg_pval_df.to_excel(writer, sheet_name='4 P-val', index=False)

  seg5_seg_diff_df.to_excel(writer, sheet_name='5 Mean', index=False)
  seg5_seg_pval_df.to_excel(writer, sheet_name='5 P-val', index=False)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:6: FutureWarning: Use of **kwargs is deprecated, use engine_kwargs instead.

# %% [markdown]
# #### Descriptor Variables

# %%
# Get descriptor variables population mean
desc_pop_mean = factor_df.mean(numeric_only=True)

# %%
# Get segment differences and pvalues
seg2_desc_diff_df, seg2_desc_pval_df = get_segment_diff_pval(seg2_dict, desc_pop_mean)
seg3_desc_diff_df, seg3_desc_pval_df = get_segment_diff_pval(seg3_dict, desc_pop_mean)
seg4_desc_diff_df, seg4_desc_pval_df = get_segment_diff_pval(seg4_dict, desc_pop_mean)
seg5_desc_diff_df, seg5_desc_pval_df = get_segment_diff_pval(seg5_dict, desc_pop_mean)

# %%
# Write to excel
options = {}
options['strings_to_formulas'] = False
options['strings_to_urls'] = False

with pd.ExcelWriter('Data/descriptor_factorised_diff_pval.xlsx', options=options) as writer:  
  seg2_desc_diff_df.to_excel(writer, sheet_name='2 Mean', index=False)
  seg2_desc_pval_df.to_excel(writer, sheet_name='2 P-val', index=False)

  seg3_desc_diff_df.to_excel(writer, sheet_name='3 Mean', index=False)
  seg3_desc_pval_df.to_excel(writer, sheet_name='3 P-val', index=False)

  seg4_desc_diff_df.to_excel(writer, sheet_name='4 Mean', index=False)
  seg4_desc_pval_df.to_excel(writer, sheet_name='4 P-val', index=False)

  seg5_desc_diff_df.to_excel(writer, sheet_name='5 Mean', index=False)
  seg5_desc_pval_df.to_excel(writer, sheet_name='5 P-val', index=False)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:6: FutureWarning: Use of **kwargs is deprecated, use engine_kwargs instead.

# %% [markdown]
# ### Analyse Significant Differences

# %% [markdown]
# #### Segmentation Variables

# %%
seg2_seg_sig_diff = get_sig_diff(seg2_dict, seg2_seg_diff_df, seg2_seg_pval_df)
seg2_seg_sig_diff.sort_values("Customer")
# Out:
#               Customer        Variable                   Type  Segment Mean  \
# 0  High Value Customer         recency   Lower (p-val < 0.05)        112.35
# 2  High Value Customer       frequency  Higher (p-val < 0.05)         17.13
# 4  High Value Customer  monetary_value  Higher (p-val < 0.05)      31382.92
# 1   Low Value Customer         recency  Higher (p-val < 0.05)        341.80
# 3   Low Value Customer       frequency   Lower (p-val < 0.05)          3.70
# 5   Low Value Customer  monetary_value   Lower (p-val < 0.05)      10128.95
#
#    Population Mean  P-value
# 0           232.44    0.000
# 2            10.13    0.000
# 4         20070.56    0.002
# 1           232.44    0.000
# 3            10.13    0.000
# 5         20070.56    0.000

# %%
seg3_seg_sig_diff = get_sig_diff(seg3_dict, seg3_seg_diff_df, seg3_seg_pval_df)
seg3_seg_sig_diff.sort_values("Customer")
# Out:
#                 Customer        Variable                   Type  Segment Mean  \
# 0    High Value Customer         recency   Lower (p-val < 0.05)         64.98
# 3    High Value Customer       frequency  Higher (p-val < 0.05)         26.26
# 5    High Value Customer  monetary_value  Higher (p-val < 0.05)      41731.24
# 2     Low Value Customer         recency  Higher (p-val < 0.05)        341.80
# 4     Low Value Customer       frequency   Lower (p-val < 0.05)          3.70
# 6     Low Value Customer  monetary_value   Lower (p-val < 0.05)      10128.95
# 1  Medium Value Customer         recency   Lower (p-val < 0.05)        147.13
#
#    Population Mean  P-value
# 0           232.44   0.0000
# 3            10.13   0.0000
# 5         20070.56   0.0025
# 2           232.44   0.0000
# 4            10.13   0.0000
# 6         20070.56   0.0000
# 1           232.44   0.0000

# %%
seg4_seg_sig_diff = get_sig_diff(seg4_dict, seg4_seg_diff_df, seg4_seg_pval_df)
seg4_seg_sig_diff.sort_values("Customer")
# Out:
#                 Customer        Variable                   Type  Segment Mean  \
# 0    High Value Customer         recency   Lower (p-val < 0.05)         64.98
# 3    High Value Customer       frequency  Higher (p-val < 0.05)         26.26
# 6    High Value Customer  monetary_value  Higher (p-val < 0.05)      41731.24
# 2          Lost Customer         recency  Higher (p-val < 0.05)        505.38
# 5          Lost Customer       frequency   Lower (p-val < 0.05)          2.12
# 8          Lost Customer  monetary_value   Lower (p-val < 0.05)       7805.17
# 4     Low Value Customer       frequency   Lower (p-val < 0.05)          4.55
# 7     Low Value Customer  monetary_value   Lower (p-val < 0.05)      11387.67
# 1  Medium Value Customer         recency   Lower (p-val < 0.05)        147.13
#
#    Population Mean  P-value
# 0           232.44   0.0000
# 3            10.13   0.0000
# 6         20070.56   0.0025
# 2           232.44   0.0000
# 5            10.13   0.0000
# 8         20070.56   0.0000
# 4            10.13   0.0000
# 7         20070.56   0.0000
# 1           232.44   0.0000

# %%
seg5_seg_sig_diff = get_sig_diff(seg5_dict, seg5_seg_diff_df, seg5_seg_pval_df)
seg5_seg_sig_diff.sort_values("Customer")
# Out:
#                  Customer        Variable                   Type  \
# 1     High Value Customer         recency   Lower (p-val < 0.05)
# 6     High Value Customer       frequency  Higher (p-val < 0.05)
# 11    High Value Customer  monetary_value  Higher (p-val < 0.05)
# 4           Lost Customer         recency  Higher (p-val < 0.05)
# 9           Lost Customer       frequency   Lower (p-val < 0.05)
# 14          Lost Customer  monetary_value   Lower (p-val < 0.05)
# 3      Low Value Customer         recency  Higher (p-val < 0.05)
# 8      Low Value Customer       frequency   Lower (p-val < 0.05)
# 13     Low Value Customer  monetary_value   Lower (p-val < 0.05)
# 2   Medium Value Customer         recency   Lower (p-val < 0.05)
# 7   Medium Value Customer       frequency   Lower (p-val < 0.05)
# 12  Medium Value Customer  monetary_value   Lower (p-val < 0.05)
# 0            Top Customer         recency   Lower (p-val < 0.05)
# 5            Top Customer       frequency  Higher (p-val < 0.05)
# 10           Top Customer  monetary_value  Higher (p-val < 0.05)
#
#     Segment Mean  Population Mean  P-value
# 1         111.08           232.44   0.0000
# 6          13.77            10.13   0.0028
# 11      29561.48         20070.56   0.0249
# 4         534.12           232.44   0.0000
# 9           1.78            10.13   0.0000
# 14       7955.61         20070.56   0.0000
# 3         296.20           232.44   0.0020
# 8           3.83            10.13   0.0000
# 13       9915.65         20070.56   0.0000
# 2         199.12           232.44   0.0309
# 7           6.57            10.13   0.0000
# 12      13903.18         20070.56   0.0014
# 0          57.22           232.44   0.0000
# 5          30.18            10.13   0.0000
# 10      47536.05         20070.56   0.0066

# %% [markdown]
# #### Descriptor Variables

# %%
seg2_desc_sig_diff = get_sig_diff(seg2_dict, seg2_desc_diff_df, seg2_desc_pval_df)
seg2_desc_sig_diff.sort_values("Customer")
# Out:
#               Customer   Variable                   Type  Segment Mean  \
# 1  High Value Customer   factor_8  Higher (p-val < 0.05)          9.86
# 2  High Value Customer  factor_17  Higher (p-val < 0.05)         -0.00
# 0   Low Value Customer   factor_7  Higher (p-val < 0.10)          1.30
#
#    Population Mean  P-value
# 1             9.63   0.0447
# 2            -0.01   0.0099
# 0             1.13   0.0901

# %%
seg3_desc_sig_diff = get_sig_diff(seg3_dict, seg3_desc_diff_df, seg3_desc_pval_df)
seg3_desc_sig_diff.sort_values("Customer")
# Out:
#                 Customer   Variable                   Type  Segment Mean  \
# 2    High Value Customer  factor_14  Higher (p-val < 0.10)          0.13
# 0     Low Value Customer   factor_7  Higher (p-val < 0.10)          1.30
# 1  Medium Value Customer   factor_8  Higher (p-val < 0.05)          9.98
# 3  Medium Value Customer  factor_17  Higher (p-val < 0.05)          0.00
#
#    Population Mean  P-value
# 2             0.05   0.0509
# 0             1.13   0.0901
# 1             9.63   0.0077
# 3            -0.01   0.0000

# %%
seg4_desc_sig_diff = get_sig_diff(seg4_dict, seg4_desc_diff_df, seg4_desc_pval_df)
seg4_desc_sig_diff.sort_values("Customer")
# Out:
#                 Customer   Variable                   Type  Segment Mean  \
# 3    High Value Customer  factor_14  Higher (p-val < 0.10)          0.13
# 0          Lost Customer   factor_2   Lower (p-val < 0.05)         20.06
# 4          Lost Customer  factor_14   Lower (p-val < 0.05)          0.00
# 2     Low Value Customer   factor_8   Lower (p-val < 0.10)          9.32
# 1  Medium Value Customer   factor_8  Higher (p-val < 0.05)          9.98
# 5  Medium Value Customer  factor_17  Higher (p-val < 0.05)          0.00
#
#    Population Mean  P-value
# 3             0.05   0.0509
# 0            21.75   0.0010
# 4             0.05   0.0000
# 2             9.63   0.0776
# 1             9.63   0.0077
# 5            -0.01   0.0000

# %%
seg5_desc_sig_diff = get_sig_diff(seg5_dict, seg5_desc_diff_df, seg5_desc_pval_df)
seg5_desc_sig_diff.sort_values("Customer")
# Out:
#                  Customer   Variable                   Type  Segment Mean  \
# 3     High Value Customer   factor_7   Lower (p-val < 0.10)          0.83
# 5     High Value Customer   factor_8  Higher (p-val < 0.05)          9.95
# 6     High Value Customer  factor_12   Lower (p-val < 0.10)          0.03
# 10    High Value Customer  factor_17  Higher (p-val < 0.05)          0.00
# 2           Lost Customer   factor_2   Lower (p-val < 0.05)         19.82
# 9           Lost Customer  factor_14   Lower (p-val < 0.05)          0.00
# 0      Low Value Customer   factor_0  Higher (p-val < 0.10)         18.78
# 1      Low Value Customer   factor_1  Higher (p-val < 0.05)         20.05
# 4      Low Value Customer   factor_7  Higher (p-val < 0.10)          1.38
# 7   Medium Value Customer  factor_12  Higher (p-val < 0.10)          0.15
# 8   Medium Value Customer  factor_14   Lower (p-val < 0.05)          0.02
#
#     Population Mean  P-value
# 3              1.13   0.0553
# 5              9.63   0.0472
# 6              0.07   0.0570
# 10            -0.01   0.0000
# 2             21.75   0.0018
# 9              0.05   0.0000
# 0             17.75   0.0917
# 1             19.24   0.0377
# 4              1.13   0.0858
# 7              0.07   0.0516
# 8              0.05   0.0402
